# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %%
# Veriyi oku
df = pd.read_csv('ai4i2020.csv') # Dosya adın neyse onu yaz

# Sadece sayısal sütunları seç (KNIME'daki Column Filter gibi)
# Örnek: Air temperature, Process temperature, Rotational speed, Torque, Tool wear
features = ['Air temperature [K]', 'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]']
X = df[features]

# Normalizasyon (KNIME'daki Normalizer gibi)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
